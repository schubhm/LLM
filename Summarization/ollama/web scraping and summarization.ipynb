# %% [markdown]
# ## Libraries learnt -
#  - os
# - requests
# - dotenv
# - bs4
# - IPython.Markdown
# - openai
#
# Summarization - This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# ## Connect to OpenAI

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()
ollama_with_openai=OpenAI(base_url="http://localhost:11434/v1", api_key='ollama')

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# Let's try one out. Change the website and add print statements to follow along.

sp = Website("https://linkedin.com/in/schubhm")
print(sp.title)
print(sp.text)
# Out:
# Shubham Panday - Audacy, Inc. | LinkedIn
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Shubham Panday
# Sign in to view Shubham’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# United States
# Contact Info
# Sign in to view Shubham’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# 1K followers
# 500+ connections
# See your mutual connections
# View mutual connections with Shubham
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Join to view profile
# Message
# Sign in to view Shubham’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Audacy, Inc.
# Report this profile
# About
# Shubham Panday is a Solutions Architect, with over 14 years of experience in designing…
# see more
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# Experience & Education
# Audacy, Inc.
# ********* *********
# *********
# ***** *********
# **
# ****** **********
# View Shubham’s full experience
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# Licenses & Certifications
# Snowflake Fundamentals Training (T3)
# Snowflake
# Issued
# Apr 2022
# Credential ID cc4ca529-e1ed-35b4-af7f-142a463d4e6f
# See credential
# EY Emerging technology - Blockchain - Bronze
# EY
# Issued
# Dec 2018
# See credential
# Ethereum and Solidity: The Complete Developer's Guide
# Udemy & Stephen Grider
# Issued
# Nov 2018
# Credential ID UC-E61DP6CE
# See credential
# Blockchain Advanced Level: Uses Beyond Bitcoin 2018 by George Levy
# Udemy
# Issued
# Aug 2018
# Credential ID UC-RKDEZ9X0
# See credential
# EY Artificial intelligence - Bronze
# EY
# Issued
# May 2018
# See credential
# Oracle Cloud Customer Connect – Green Ribbon Member
# Oracle
# Issued
# May 2018
# See credential
# Oracle SOA Suite 12c Certified Implementation Specialist
# Oracle
# Issued
# May 2018
# See credential
# ChatBots: Messenger ChatBot - DialogFlow and nodejs
# Jana Bergant & Udemy
# Issued
# Apr 2018
# Credential ID UC-BKOR2C9T
# See credential
# AWS Certified Cloud Practitioner
# Amazon Web Services (AWS)
# Issued
# Jun 2020
# Expires
# Mar 2025
# See credential
# MuleSoft Certified Developer - Level 1 (Mule 4)
# MuleSoft
# Issued
# Mar 2020
# Expires
# Mar 2022
# See credential
# Join now to see all certifications
# Honors & Awards
# Exceptional Client Service Award
# EY
# Jul 2018
# Extra Miler Award
# Spot Award
# EY
# Nov 2017
# For Successful Go-Live of Wayne
# Extra Miler Award
# EY
# Sep 2017
# Highest Performing Team at EY
# Spot Award
# EY
# May 2017
# For great work and good conduct in the team.
# Limca book of record
# Limca
# Nov 2015
# All India record to distribute maximum stationery in a day
# IBSFIN Tech Award
# IBSFIN Tech
# Apr 2015
# Received for implementation of Treasury Module in Snapdeal.
# Handled the Web Services development.
# Bravo Award
# Infosys
# Mar 2013
# Quarterly Award for best performance in the Team.
# Recommendations received
# Craig Kunzel
# “I have had the pleasure of working with Shubham on a couple of projects over the past 5 years.  He was my primary technical architect. His technical skills are top notch.  He is an Oracle EBS guru, both for functional and technical. Over the last two years I have asked a lot of him.  I asked him to learn SOA and the Oracle Work and Asset Management software.  He stepped up and learned both swiftly.   He earned my respect and trust very quickly.  This enabled me to briefly describe projects to him, and let him take ownership to complete them.   Communication is the most important aspect on any offsite or offshore resources.  His ability to take a functional design and fill in the blanks and ask the right questions for any gaps was excellent.”
# Mark Wood
# “I have worked with Shubham for the last two years. His role on our project is as an Oracle eBusiness technical analyst. On our project, Shubham has worked in the Procure to Pay Modules, Inventory, GL, Projects Timekeeping and HR modules. Shubham knows the Oracle eBusiness technical framework and has wrote numerous interfaces as well as extensions and customizations. He is also able to communicate well with the functional team and able to translate functional designs to technical solutions. I would recommend him for an eBusiness technical role.”
# 3 people have recommended Shubham
# Join now to view
# View Shubham’s full profile
# See who you know in common
# Get introduced
# Contact Shubham directly
# Join to view full profile
# Sign in
# Stay updated on your professional world
# Sign in
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# Other similar profiles
# Vishal Nigam
# Mississauga, ON
# Connect
# Kulpreet Singh
# Victoria, BC
# Connect
# Karan Kambo
# Greater Toronto Area, Canada
# Connect
# Lin Zhu
# Denver Metropolitan Area
# Connect
# Monowar Chowdhury
# Greater Toronto Area, Canada
# Connect
# Edouard Kopczuk, M.Eng.
# Montreal, QC
# Connect
# Usman R.
# United States
# Connect
# Rahul Goel
# Greater Toronto Area, Canada
# Connect
# Mostafa Nasr
# Canada
# Connect
# Rohit Roy
# Oakville, ON
# Connect
# Explore collaborative articles
# We’re unlocking community knowledge in a new way. Experts add insights directly into each article, started with the help of AI.
# Explore More
# Others named
# Shubham Panday
# Shubham Panday
# Planning Engineer @ NARSI | Project Planning.
# Gurgaon
# Shubham Panday
# QA Automation Engineer @Infostride Technologies India | TypeScript | Jenkins | Cypress | Playwright | Linux | Docker | Agile Methodology | Functional Testing | API Testing | Python | CI/CD |
# Indore
# Shubham Panday
# Embedded Software lead | C/C++/Python | Labview | KiCad | LTSpice | Altium & Hardware developer.
# Mumbai
# shubham panday
# PROCUREMENT MANAGER (PRISM JOHNSON LIMITED)
# Bahadurgarh
# 149 others named Shubham Panday are on LinkedIn
# See others named
# Shubham Panday
# Add new skills with these courses
# 22m
# Building a Personalized Chatbot with OpenAI and LangChain
# 1h 12m
# Chat with Your Data Using ChatGPT
# 1h 1m
# Responsible AI on AWS: Bedrock Guardrails, Amazon Q Security, and SageMaker Clarify
# See all courses
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# View Shubham’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT4o have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(sp))
# Out:
# You are looking at a website titled Shubham Panday - Audacy, Inc. | LinkedIn
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Shubham Panday
# Sign in to view Shubham’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# United States
# Contact Info
# Sign in to view Shubham’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# 1K followers
# 500+ connections
# See your mutual connections
# View mutual connections with Shubham
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Join to view profile
# Message
# Sign in to view Shubham’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Audacy, Inc.
# Report this profile
# About
# Shubham Panday is a Solutions Architect, with over 14 years of experience in designing…
# see more
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# Experience & Education
# Audacy, Inc.
# ********* *********
# *********
# ***** *********
# **
# ****** **********
# View Shubham’s full experience
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# Licenses & Certifications
# Snowflake Fundamentals Training (T3)
# Snowflake
# Issued
# Apr 2022
# Credential ID cc4ca529-e1ed-35b4-af7f-142a463d4e6f
# See credential
# EY Emerging technology - Blockchain - Bronze
# EY
# Issued
# Dec 2018
# See credential
# Ethereum and Solidity: The Complete Developer's Guide
# Udemy & Stephen Grider
# Issued
# Nov 2018
# Credential ID UC-E61DP6CE
# See credential
# Blockchain Advanced Level: Uses Beyond Bitcoin 2018 by George Levy
# Udemy
# Issued
# Aug 2018
# Credential ID UC-RKDEZ9X0
# See credential
# EY Artificial intelligence - Bronze
# EY
# Issued
# May 2018
# See credential
# Oracle Cloud Customer Connect – Green Ribbon Member
# Oracle
# Issued
# May 2018
# See credential
# Oracle SOA Suite 12c Certified Implementation Specialist
# Oracle
# Issued
# May 2018
# See credential
# ChatBots: Messenger ChatBot - DialogFlow and nodejs
# Jana Bergant & Udemy
# Issued
# Apr 2018
# Credential ID UC-BKOR2C9T
# See credential
# AWS Certified Cloud Practitioner
# Amazon Web Services (AWS)
# Issued
# Jun 2020
# Expires
# Mar 2025
# See credential
# MuleSoft Certified Developer - Level 1 (Mule 4)
# MuleSoft
# Issued
# Mar 2020
# Expires
# Mar 2022
# See credential
# Join now to see all certifications
# Honors & Awards
# Exceptional Client Service Award
# EY
# Jul 2018
# Extra Miler Award
# Spot Award
# EY
# Nov 2017
# For Successful Go-Live of Wayne
# Extra Miler Award
# EY
# Sep 2017
# Highest Performing Team at EY
# Spot Award
# EY
# May 2017
# For great work and good conduct in the team.
# Limca book of record
# Limca
# Nov 2015
# All India record to distribute maximum stationery in a day
# IBSFIN Tech Award
# IBSFIN Tech
# Apr 2015
# Received for implementation of Treasury Module in Snapdeal.
# Handled the Web Services development.
# Bravo Award
# Infosys
# Mar 2013
# Quarterly Award for best performance in the Team.
# Recommendations received
# Craig Kunzel
# “I have had the pleasure of working with Shubham on a couple of projects over the past 5 years.  He was my primary technical architect. His technical skills are top notch.  He is an Oracle EBS guru, both for functional and technical. Over the last two years I have asked a lot of him.  I asked him to learn SOA and the Oracle Work and Asset Management software.  He stepped up and learned both swiftly.   He earned my respect and trust very quickly.  This enabled me to briefly describe projects to him, and let him take ownership to complete them.   Communication is the most important aspect on any offsite or offshore resources.  His ability to take a functional design and fill in the blanks and ask the right questions for any gaps was excellent.”
# Mark Wood
# “I have worked with Shubham for the last two years. His role on our project is as an Oracle eBusiness technical analyst. On our project, Shubham has worked in the Procure to Pay Modules, Inventory, GL, Projects Timekeeping and HR modules. Shubham knows the Oracle eBusiness technical framework and has wrote numerous interfaces as well as extensions and customizations. He is also able to communicate well with the functional team and able to translate functional designs to technical solutions. I would recommend him for an eBusiness technical role.”
# 3 people have recommended Shubham
# Join now to view
# View Shubham’s full profile
# See who you know in common
# Get introduced
# Contact Shubham directly
# Join to view full profile
# Sign in
# Stay updated on your professional world
# Sign in
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# Other similar profiles
# Vishal Nigam
# Mississauga, ON
# Connect
# Kulpreet Singh
# Victoria, BC
# Connect
# Karan Kambo
# Greater Toronto Area, Canada
# Connect
# Lin Zhu
# Denver Metropolitan Area
# Connect
# Monowar Chowdhury
# Greater Toronto Area, Canada
# Connect
# Edouard Kopczuk, M.Eng.
# Montreal, QC
# Connect
# Usman R.
# United States
# Connect
# Rahul Goel
# Greater Toronto Area, Canada
# Connect
# Mostafa Nasr
# Canada
# Connect
# Rohit Roy
# Oakville, ON
# Connect
# Sushant V
# Edmonton, AB
# Connect
# Shahid Mian, MACS (Snr) CP
# Analytics and Reporting at Ontario Ministry of Education
# Canada
# Connect
# Prashant Jha
# Canada
# Connect
# Saurabh Sahu
# Toronto, ON
# Connect
# Sumit Verma
# Toronto, ON
# Connect
# Aziz Amirali
# Brampton, ON
# Connect
# Richa Khosla
# ABAP|HANA technical consultant| (PCF) Pivotal Cloud foundry certified
# Toronto, ON
# Connect
# Eugene Zozulya
# Digital & App Innovation Sales Lead ✦ On the mission to enable organizations to maximize their full potential by going digital
# Toronto, ON
# Connect
# Jason Matte
# Greater Ottawa Metropolitan Area
# Connect
# Nodir Fayzullaev
# Canada
# Connect
# Show more profiles
# Show fewer profiles
# Explore collaborative articles
# We’re unlocking community knowledge in a new way. Experts add insights directly into each article, started with the help of AI.
# Explore More
# Others named
# Shubham Panday
# Shubham Panday
# Planning Engineer @ NARSI | Project Planning.
# Gurgaon
# Shubham Panday
# QA Automation Engineer @Infostride Technologies India | TypeScript | Jenkins | Cypress | Playwright | Linux | Docker | Agile Methodology | Functional Testing | API Testing | Python | CI/CD |
# Indore
# Shubham Panday
# Embedded Software lead | C/C++/Python | Labview | KiCad | LTSpice | Altium & Hardware developer.
# Mumbai
# shubham panday
# PROCUREMENT MANAGER (PRISM JOHNSON LIMITED)
# Bahadurgarh
# 149 others named Shubham Panday are on LinkedIn
# See others named
# Shubham Panday
# Add new skills with these courses
# 52m
# Enterprise AI Solutions with AWS: Amazon Q Business, Bedrock Knowledge Bases, and SageMaker MLOps
# 1h 1m
# Responsible AI on AWS: Bedrock Guardrails, Amazon Q Security, and SageMaker Clarify
# 46m
# AWS AI Automation Foundations: Command Line Interface (CLI) with Amazon Q in AWS CloudShell
# See all courses
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# View Shubham’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
messages = [
    {"role": "system", "content": "You are a snarky assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

ollama_messages = [{"role": "user", "content": "What is 2 + 2?"}]

# %%
# To give you a preview -- calling OpenAI with system and user messages:

response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
print(response.choices[0].message.content)
# Out:
# Oh, that's a tough one! Let me consult my vast database of knowledge... Ah yes, it’s 4. Shocking, right?

# %%
# using ollama_with_openai
response = ollama_with_openai.chat.completions.create(model="llama3.2", messages=ollama_messages)
print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

def ollama_messages_for(website):
    return [{"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# Try this out, and then try for a few more websites
messages_for(sp)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': "You are looking at a website titled Shubham Panday - Audacy, Inc. | LinkedIn\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nSkip to main content\nLinkedIn\nArticles\nPeople\nLearning\nJobs\nGames\nGet the app\nJoin now\nSign in\nShubham Panday\nSign in to view Shubham’s full profile\nSign in\nWelcome back\nEmail or phone\nPassword\nShow\nForgot password?\nSign in\nor\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nNew to LinkedIn?\nJoin now\nor\nNew to LinkedIn?\nJoin now\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nUnited States\nContact Info\nSign in to view Shubham’s full profile\nSign in\nWelcome back\nEmail or phone\nPassword\nShow\nForgot password?\nSign in\nor\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nNew to LinkedIn?\nJoin now\nor\nNew to LinkedIn?\nJoin now\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\n1K followers\n500+ connections\nSee your mutual connections\nView mutual connections with Shubham\nSign in\nWelcome back\nEmail or phone\nPassword\nShow\nForgot password?\nSign in\nor\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nNew to LinkedIn?\nJoin now\nor\nNew to LinkedIn?\nJoin now\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nJoin to view profile\nMessage\nSign in to view Shubham’s full profile\nSign in\nWelcome back\nEmail or phone\nPassword\nShow\nForgot password?\nSign in\nor\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nNew to LinkedIn?\nJoin now\nor\nNew to LinkedIn?\nJoin now\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nAudacy, Inc.\nReport this profile\nAbout\nShubham Panday is a Solutions Architect, with over 14 years of experience in designing…\nsee more\nWelcome back\nEmail or phone\nPassword\nShow\nForgot password?\nSign in\nor\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nNew to LinkedIn?\nJoin now\nExperience & Education\nAudacy, Inc.\n********* *********\n*********\n***** *********\n**\n****** **********\nView Shubham’s full experience\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nSign in\nWelcome back\nEmail or phone\nPassword\nShow\nForgot password?\nSign in\nor\nBy clicking Continue to join or sign in, you agree to LinkedIn’s\nUser Agreement\n,\nPrivacy Policy\n, and\nCookie Policy\n.\nNew to LinkedIn?\nJoin now\nLicenses & Certifications\nSnowflake Fundamentals Training (T3)\nSnowflake\nIssued\nApr 2022\nCredential ID cc4ca529-e1ed-35b4-af7f-142a463d4e6f\nSee credential\nEY Emerging technology - Blockchain - Bronze\nEY\nIssued\nDec 2018\nSee credential\nEthereum and Solidity: The Complete Developer's Guide\nUdemy & Stephen Grider\nIssued\nNov 2018\nCredential ID UC-E61DP6CE\nSee credential\nBlockchain Advanced Level: Uses Beyond Bitcoin 2018 by George Levy\nUdemy\nIssued\nAug 2018\nCredential ID UC-RKDEZ9X0\nSee credential\nEY Artificial intelligence - Bronze\nEY\nIssued\nMay 2018\nSee credential\nOracle Cloud Customer Connect – Green Ribbon Member\nOracle\nIssued\nMay 2018\nSee credential\nOracle SOA Suite 12c Certified Implementation Specialist\nOracle\nIssued\nMay 2018\nSee credential\nChatBots: Messenger ChatBot - DialogFlow and nodejs\nJana Bergant & Udemy ...

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = Website(url)
    response = ollama_with_openai.chat.completions.create(
        model = "llama3.2",
        messages = ollama_messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://WWW.LINKEDIN.com/in/schubhm")
# Out:
# "Here is a summary of the Shubham Panday website in markdown:\n\n**About**\n================\n\n* Shubham Panday is a Solutions Architect with over 14 years of experience in designing and implementing solutions.\n* He has worked with various companies, including Audacy, Inc.\n\n**Professional Experience**\n=========================\n\n* Audacy, Inc. (current)\n* Experience & Education section provides details on his work experience, licenses, and certifications.\n* Links to view his full experience profile.\n\n**Skills and Certifications**\n==========================\n\n* Snowflake Fundamentals Training (T3) certification\n* EY Emerging technology - Blockchain - Bronze certification\n* Ethereum and Solidity: The Complete Developer's Guide certification\n* Other certifications listed under Licenses & Certifications section.\n\n**Recommendations and Honors**\n==============================\n\n* Recommendations from professionals who have worked with him, highlighting his technical skills and work ethic.\n* Awards and honors received for exceptional client service, extra miler awards, and other achievements.\n\nOverall, the website provides an overview of Shubham Panday's professional experience, skills, and certifications."

# %%
# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://WWW.LINKEDIN.com/in/schubhm")
# Out:
# **Summary of Shubham Panday's LinkedIn Profile:**
#
# Shubham Panday is a Solutions Architect with over 14 years of experience in designing and implementing solutions. He currently works at Audacy, Inc., but his previous work experience includes various roles such as Procurement Manager and QA Automation Engineer.
#
# **Experience & Education:**
#
# * Solutions Architect, Audacy, Inc.
# * Procurement Manager (PRISM Johnson Limited)
# * QA Automation Engineer (Infostride Technologies India)
#
# **Licenses & Certifications:**
#
# * Snowflake Fundamentals Training (T3)
# * EY Emerging technology - Blockchain - Bronze
# * Ethereum and Solidity: The Complete Developer's Guide (Udemy)
# * MuleSoft Certified Developer - Level 1 (Mule 4)
# * AWS Certified Cloud Practitioner
# * Oracle SOA Suite 12c Certified Implementation Specialist
#
# **Honors & Awards:**
#
# * Exceptional Client Service Award (EY)
# * Extra Miler Award (EY)
# * Highest Performing Team at EY
# * Limca Book of Record (IBSFIN Tech)
#
# **Recommendations:**
#
# There are two recommendations for Shubham Panday from his former colleagues, Craig Kunzel and Mark Wood. They praise Shubham's technical skills, ability to communicate effectively, and teamwork.
#
# **News/Announcements:**
#
# None mentioned on this profile.

# %%
display_summary("https://www.openai.com")
# Out:
# # Website Summary
#
# The website titled "No title found" appears to be displaying a message prompting users to enable JavaScript and cookies in their web browser to continue accessing its content. There are no specific details, news, or announcements provided beyond this request.
#
# It is likely that the actual content of the site is unavailable until the required settings are adjusted.
